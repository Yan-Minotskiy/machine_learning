# %% [markdown]
# # Визуализация данных

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Визуализация библиотеки Pandas

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
df['math score'].hist()

# %%
df['writing score'].plot()

# %%
df.plot.scatter(x = 'math score', y ='reading score')

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series.plot.pie(figsize=(6, 6))

# %% [markdown]
# ## Matplotlib

# %%
fig, ax = plt.subplots()  
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
import matplotlib.image as mpimg
img = mpimg.imread('https://github.com/Yan-Minotskiy/labOS/raw/master/screenshots/docker.png')
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
# Out:
# (array([1.26930e+04, 1.27000e+02, 1.36000e+02, 9.00000e+01, 9.70000e+01,
#         7.90000e+01, 1.41100e+03, 9.19000e+03, 2.27180e+04, 2.39380e+04,
#         1.30090e+04, 6.00200e+03, 3.13500e+03, 1.43400e+03, 3.08000e+02,
#         1.92000e+02, 2.99000e+02, 3.27000e+02, 3.19000e+02, 3.17000e+02,
#         2.59000e+02, 2.22000e+02, 2.29000e+02, 2.29000e+02, 2.48000e+02,
#         2.41000e+02, 3.25000e+02, 2.70000e+02, 2.92000e+02, 3.20000e+02,
#         4.28000e+02, 6.80000e+02, 1.23000e+03, 1.21100e+03, 7.69000e+02,
#         5.69000e+02, 7.10000e+02, 6.81000e+02, 6.89000e+02, 7.49000e+02,
#         7.89000e+02, 7.09000e+02, 6.31000e+02, 6.33000e+02, 5.97000e+02,
#         6.55000e+02, 6.14000e+02, 6.44000e+02, 7.66000e+02, 7.36000e+02,
#         6.73000e+02, 7.38000e+02, 6.91000e+02, 6.91000e+02, 6.48000e+02,
#         1.03300e+03, 6.85000e+02, 6.11000e+02, 6.41400e+03, 4.44700e+03,
#         2.55900e+03, 2.43100e+03, 2.45900e+03, 4.29100e+03, 5.51100e+03,
#         5.70400e+03, 6.69200e+03, 6.37000e+03, 7.28300e+03, 8.79900e+03,
#         5.41700e+03, 8.48000e+03, 1.03880e+04, 8.11400e+03, 7.53500e+03,
#         7.52700e+03, 8.26900e+03, 7.86500e+03, 9.03500e+03, 6.12570e+04,
#         8.00600e+03, 5.67300e+03, 8.67000e+03, 2.59800e+03, 2.37400e+03,
#         4.26500e+03, 2.41300e+03, 2.45600e+03, 5.16000e+02, 3.44000e+02,
#         4.09000e+02, 3.87000e+02, 4.53000e+02, 4.39000e+02, 3.86000e+02,
#         3.88000e+02, 3.92000e+02, 4.54000e+02, 7.12000e+02, 1.26700e+03,
#         6.23000e+02, 5.63000e+02, 9.58000e+02, 6.26000e+02, 5.46000e+02,
#         6.58000e+02, 7.74000e+02, 6.92000e+02, 7.04000e+02, 8.55000e+02,
#         8.68000e+02, 8.88000e+02, 1.01600e+03, 1.03900e+03, 1.10300e+03,
#         1.30400e+03, 1.17000e+03, 1.23600e+03, 1.07200e+03, 1.12300e+03,
#         9.86000e+02, 1.05100e+03, 1.16200e+03, 1.07900e+03, 1.04800e+03,
#         1.18200e+03, 1.11100e+03, 1.24700e+03, 1.26100e+03, 1.33600e+03,
#         1.69100e+03, 1.97000e+03, 2.26900e+03, 1.61900e+03, 1.25500e+03,
#         1.04500e+03, 1.07100e+03, 1.29000e+03, 1.29300e+03, 1.09000e+03,
#         1.18800e+03, 1.18900e+03, 1.41200e+03, 1.47800e+03, 1.66200e+03,
#         1.73800e+03, 1.92400e+03, 2.39000e+03, 2.83300e+03, 3.14800e+03,
#         3.91700e+03, 4.70600e+03, 5.54600e+03, 6.94100e+03, 7.01400e+03,
#         7.00300e+03, 7.09000e+03, 7.18500e+03, 7.75700e+03, 7.76600e+03,
#         8.86500e+03, 9.43300e+03, 1.00810e+04, 1.09270e+04, 1.13420e+04,
#         1.16000e+04, 1.23810e+04, 1.37100e+04, 1.42400e+04, 1.42280e+04,
#         1.57300e+04, 1.61560e+04, 1.78420e+04, 2.04970e+04, 2.27020e+04,
#         2.43310e+04, 2.66160e+04, 2.65850e+04, 2.56540e+04, 2.56970e+04,
#         2.31880e+04, 1.69980e+04, 1.63400e+04, 1.21740e+04, 8.48800e+03,
#         5.51100e+03, 4.51400e+03, 3.93400e+03, 3.23100e+03, 2.98600e+03,
#         2.76000e+03, 2.68200e+03, 2.54300e+03, 2.48700e+03, 2.52200e+03,
#         2.44400e+03, 2.39000e+03, 2.46300e+03, 2.49000e+03, 2.28400e+03,
#         2.33300e+03, 2.47100e+03, 2.33900e+03, 2.34000e+03, 3.03800e+03,
#         2.62800e+03, 2.79600e+03, 2.81400e+03, 3.10400e+03, 3.16700e+03,
#         3.39700e+03, 4.64800e+03, 4.52300e+03, 7.21700e+03, 5.91400e+03,
#         5.99400e+03, 8.25800e+03, 1.05850e+04, 1.06480e+04, 1.31930e+04,
#         1.47140e+04, 1.47950e+04, 2.78630e+04, 2.14760e+04, 1.55970e+04,
#         1.78260e+04, 1.05040e+04, 1.26960e+04, 3.15250e+04, 2.30750e+04,
#         1.92670e+04, 4.74100e+04, 1.67240e+04, 1.09410e+04, 2.06950e+04,
#         3.12600e+04, 2.90760e+04, 3.30140e+04, 1.97750e+04, 1.30870e+04,
#         4.88400e+03, 7.23200e+03, 8.77100e+03, 6.02000e+03, 3.62600e+04,
#         1.84300e+03, 1.69900e+03, 1.67000e+03, 1.55900e+03, 1.35700e+03,
#         1.12900e+03, 1.06100e+03, 8.08000e+02, 1.61400e+03, 4.91000e+02,
#         5.17503e+05]),
#  array([0.        , 0.00390625, 0.0078125 , 0.01171875, 0.015625  ,
#         0.01953125, 0.0234375 , 0.02734375, 0.03125   , 0.03515625,
#         0.0390625 , 0.04296875, 0.046875  , 0.05078125, 0.0546875 ,
#         0.05859375, 0.0625    , 0.06640625, 0.0703125 , 0.07421875,
#         0.078125  , 0.08203125, 0.0859375 , 0.08984375, 0.09375   ,
#         0.09765625, 0.1015625 , 0.10546875, 0.109375  , 0.11328125,
#         0.1171875 , 0.12109375, 0.125     , 0.12890625, 0.1328125 ,
#         0.13671875, 0.140625  , 0.14453125, 0.1484375 , 0.15234375,
#         0.15625   , 0.16015625, 0.1640625 , 0.16796875, 0.171875  ,
#         0.17578125, 0.1796875 , 0.18359375, 0.1875    , 0.19140625,
#         0.1953125 , 0.19921875, 0.203125  , 0.20703125, 0.2109375 ,
#         0.21484375, 0.21875   , 0.22265625, 0.2265625 , 0.23046875,
#         0.234375  , 0.23828125, 0.2421875 , 0.24609375, 0.25      ,
#         0.25390625, 0.2578125 , 0.26171875, 0.265625  , 0.26953125,
#         0.2734375 , 0.27734375, 0.28125   , 0.28515625, 0.2890625 ,
#         0.29296875, 0.296875  , 0.30078125, 0.3046875 , 0.30859375,
#         0.3125    , 0.31640625, 0.3203125 , 0.32421875, 0.328125  ,
#         0.33203125, 0.3359375 , 0.33984375, 0.34375   , 0.34765625,
#         0.3515625 , 0.35546875, 0.359375  , 0.36328125, 0.3671875 ,
#         0.37109375, 0.375     , 0.37890625, 0.3828125 , 0.38671875,
#         0.390625  , 0.39453125, 0.3984375 , 0.40234375, 0.40625   ,
#         0.41015625, 0.4140625 , 0.41796875, 0.421875  , 0.42578125,
#         0.4296875 , 0.43359375, 0.4375    , 0.44140625, 0.4453125 ,
#         0.44921875, 0.453125  , 0.45703125, 0.4609375 , 0.46484375,
#         0.46875   , 0.47265625, 0.4765625 , 0.48046875, 0.484375  ,
#         0.48828125, 0.4921875 , 0.49609375, 0.5       , 0.50390625,
#         0.5078125 , 0.51171875, 0.515625  , 0.51953125, 0.5234375 ,
#         0.52734375, 0.53125   , 0.53515625, 0.5390625 , 0.54296875,
#         0.546875  , 0.55078125, 0.5546875 , 0.55859375, 0.5625    ,
#         0.56640625, 0.5703125 , 0.57421875, 0.578125  , 0.58203125,
#         0.5859375 , 0.58984375, 0.59375   , 0.59765625, 0.6015625 ,
#         0.60546875, 0.609375  , 0.61328125, 0.6171875 , 0.62109375,
#         0.625     , 0.62890625, 0.6328125 , 0.63671875, 0.640625  ,
#         0.64453125, 0.6484375 , 0.65234375, 0.65625   , 0.66015625,
#         0.6640625 , 0.66796875, 0.671875  , 0.67578125, 0.6796875 ,
#         0.68359375, 0.6875    , 0.69140625, 0.6953125 , 0.69921875,
#         0.703125  , 0.70703125, 0.7109375 , 0.71484375, 0.71875   ,
#         0.72265625, 0.7265625 , 0.73046875, 0.734375  , 0.73828125,
#         0.7421875 , 0.74609375, 0.75      , 0.75390625, 0.7578125 ,
#         0.76171875, 0.765625  , 0.76953125, 0.7734375 , 0.77734375,
#         0.78125   , 0.78515625, 0.7890625 , 0.79296875, 0.796875  ,
#         0.80078125, 0.8046875 , 0.80859375, 0.8125    , 0.81640625,
#         0.8203125 , 0.82421875, 0.828125  , 0.83203125, 0.8359375 ,
#         0.83984375, 0.84375   , 0.84765625, 0.8515625 , 0.85546875,
#         0.859375  , 0.86328125, 0.8671875 , 0.87109375, 0.875     ,
#         0.87890625, 0.8828125 , 0.88671875, 0.890625  , 0.89453125,
#         0.8984375 , 0.90234375, 0.90625   , 0.91015625, 0.9140625 ,
#         0.91796875, 0.921875  , 0.92578125, 0.9296875 , 0.93359375,
#         0.9375    , 0.94140625, 0.9453125 , 0.94921875, 0.953125  ,
#         0.95703125, 0.9609375 , 0.96484375, 0.96875   , 0.97265625,
#         0.9765625 , 0.98046875, 0.984375  , 0.98828125, 0.9921875 ,
#         0.99609375, 1.        ], dtype=float32),
#  <a list of 256 Patch objects>)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35)

plt.show()

# %% [markdown]
# ## Seaborn

# %%
genom_dictance = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)
g = sns.heatmap(data=genom_dictance, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
flowers = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
for column in flowers:
    sns.kdeplot(flowers[column])

# %%
sns.violinplot(flowers['petal length'])

# %%
sns.pairplot(flowers, hue="species")
